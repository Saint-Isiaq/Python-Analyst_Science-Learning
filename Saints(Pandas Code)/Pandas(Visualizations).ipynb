# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\USER\Desktop\SaintsAnaconda\Ice Cream Ratings.csv" ,index_col = 'Date')
df
# Out:
#           Flavor Rating  Texture Rating  Overall Rating
# Date
# 1/1/2022       0.223090        0.040220        0.600129
# 1/2/2022       0.635886        0.938476        0.106264
# 1/3/2022       0.442323        0.044154        0.598112
# 1/4/2022       0.389128        0.549676        0.489353
# 1/5/2022       0.386887        0.519439        0.988280
# 1/6/2022       0.877984        0.193588        0.832827
# 1/7/2022       0.140995        0.325110        0.105147

# %% [markdown]
# ## Plotting a basic line Graph
#      """putting in Graph Titles and x and y labels,
#     and Splitting the plotted graphs"""

# %% [markdown]
# ## Styling the graphs

# %%
print(plt.style.available)
plt.style.use( 'seaborn-v0_8-darkgrid')
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'petroff10', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']

# %%
#df.plot(kind = 'line')  

#OR  ##Putting titles and splitting the plots

          #Code: df.plot(kind = 'line', subplots = True , title = 'Ice Cream Ratings')
df.plot(kind = 'line', title = 'Ice Cream Ratings',xlabel = 'Daily Ratings' ,ylabel = 'Scores',figsize = (6,6))
# Out:
# <Axes: title={'center': 'Ice Cream Ratings'}, xlabel='Daily Ratings', ylabel='Scores'>

# %% [markdown]
# ### Making a bar chart plots
#      all *args used in line plots can also be used here.
# ### and stacked bar plot

# %%
#Code:   df.plot(kind= 'bar')
     #Or
df.plot(kind= 'bar', stacked = True)
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# ### Specifying:
#      which columns to run visualisation for,
#      And
# ### Making an horizontal bar chart

# %%
#Code:    df['Texture Rating'].plot(kind = 'bar' ,stacked = True)
       #OR
df.plot.barh(stacked = True)
# Out:
# <Axes: >

# %% [markdown]
# ### Scattered plot
#     we specify  the x and y axis for it to work properly

# %%
df.plot.scatter(x = 'Texture Rating',y = 'Overall Rating' , s = 55 , c = 'red')
# Out:
# <Axes: xlabel='Texture Rating', ylabel='Overall Rating'>

# %% [markdown]
#  ### Histogram

# %%
#Code:  df.plot.hist()  #Dafult : a natural histogram chart

#OR

df.plot.hist(bins= 95)
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# ## Boxplot

# %%
df.boxplot()
# Out:
# <Axes: >

# %% [markdown]
# ### Area plot
#      and specifying figure size : to Make chart larger

# %%
#Code   df.plot.area()   #Default
#OR 

df.plot.area(figsize = (6 , 5))
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# ### Pie Chart

# %%
df.plot.pie(y='Flavor Rating',figsize = (6,5))
# Out:
# <Axes: ylabel='Flavor Rating'>
